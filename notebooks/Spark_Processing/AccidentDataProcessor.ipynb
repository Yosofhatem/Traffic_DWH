# %% [markdown]
# <!-- # Accident Data Processor using Spark Streaming
#
# This notebook processes accident data from a Kafka stream, transforming it into structured data and loading it into a MySQL database.
#
# --- -->
#
# <!-- HTML structure for header -->
# <div style="background-color: #4CAF50; padding: 15px; border-radius: 5px;">
#     <h2 style="color: white; text-align: center;">Accident Data Processor using Spark Streaming</h2>
# </div>
#
# # Extract Phase
#
# ### 1. Initialize Spark Session

# %%
from pyspark.sql import SparkSession

# %%
# Initialize Spark Session
spark = (
    SparkSession
    .builder
    .appName("AccidentDataProcessor")
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0,mysql:mysql-connector-java:8.0.33")
    .getOrCreate()
)

# %%
# Kafka configuration
kafka_topic = "accident-data"
kafka_bootstrap_servers = "ed-kafka:29092"

# %% [markdown]
# ## 2. Read Stream from Kafka Topic

# %%
# Read stream from Kafka topic
df_kafka = (
    spark
    .readStream
    .format("kafka")
    .option("kafka.bootstrap.servers", kafka_bootstrap_servers)
    .option("subscribe", kafka_topic)
    .option("startingOffsets", "earliest")
    .load()
)

# %% [markdown]
# ## 3. Define the Schema for Incoming JSON Data

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, TimestampType

# Define the schema for the incoming JSON data
schema = StructType([
    StructField("eventId", StringType(), True),
    StructField("eventOffset", IntegerType(), True),
    StructField("Date", StringType(), True),  
    StructField("Time", StringType(), True),  
    StructField("Easting", IntegerType(), True),
    StructField("Northing", IntegerType(), True),
    StructField("Location", StringType(), True),
    StructField("Local_Auth", StringType(), True),
    StructField("Severity", StringType(), True),
    StructField("Road_cond", StringType(), True),
    StructField("Weather", StringType(), True),
    StructField("Visibility", StringType(), True),
    StructField("Speed_Lim", IntegerType(), True),
    StructField("Cross_fac", StringType(), True),
    StructField("Cross_ctrl", StringType(), True),
    StructField("Police_ref", StringType(), True),
    StructField("Casualties", IntegerType(), True),
    StructField("OAPs", IntegerType(), True),
    StructField("Children", IntegerType(), True),
    StructField("Cycles", IntegerType(), True),
    StructField("P2W", IntegerType(), True),
    StructField("Pedestrian", IntegerType(), True),
    StructField("Vehicles", IntegerType(), True)
])

# %% [markdown]
# <!-- HTML structure for parsing data --> <div style="background-color: #F44336; padding: 15px; border-radius: 5px; color: white;"> <h3 style="text-align: center;">Parsing the Kafka Stream</h3> </div>
#
# # Transformation Phase
# ## 4. Parse the Incoming Data

# %%
from pyspark.sql.functions import from_json, col

# Parse the value column in Kafka (which is JSON) using the schema
df_parsed = df_kafka.selectExpr("CAST(value AS STRING)") \
    .select(from_json(col("value"), schema).alias("data")) \
    .select("data.*")

# %%
df_parsed.printSchema()
# Out:
# root
#  |-- eventId: string (nullable = true)
#  |-- eventOffset: integer (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- Time: string (nullable = true)
#  |-- Easting: integer (nullable = true)
#  |-- Northing: integer (nullable = true)
#  |-- Location: string (nullable = true)
#  |-- Local_Auth: string (nullable = true)
#  |-- Severity: string (nullable = true)
#  |-- Road_cond: string (nullable = true)
#  |-- Weather: string (nullable = true)
#  |-- Visibility: string (nullable = true)
#  |-- Speed_Lim: integer (nullable = true)
#  |-- Cross_fac: string (nullable = true)
#  |-- Cross_ctrl: string (nullable = true)
#  |-- Police_ref: string (nullable = true)
#  |-- Casualties: integer (nullable = true)
#  |-- OAPs: integer (nullable = true)
#  |-- Children: integer (nullable = true)
#  |-- Cycles: integer (nullable = true)
#  |-- P2W: integer (nullable = true)
#  |-- Pedestrian: integer (nullable = true)
#  |-- Vehicles: integer (nullable = true)

# %% [markdown]
# ## 5. Extract information for our Schema
#
# ### Date Dimension

# %%
from pyspark.sql.functions import  dayofmonth, month, quarter, year, date_format

df_date = df_parsed.selectExpr(
                               "CAST(eventOffset AS BIGINT) as Date_ID",
                               "to_date(Date) as Date",
                               "dayofmonth(Date) as Day", 
                               "date_format(Date, 'EEEE') as Day_Name", 
                               "month(Date) as Month", 
                               "date_format(Date, 'MMMM') as Month_Name", 
                               "quarter(Date) as Quarter", 
                               "year(Date) as Year")


# Reordering the DataFrame to match the schema order
df_date = df_date.select("Date_ID", "Date", "Day", "Day_Name", "Month", "Month_Name", "Quarter", "Year")

# %% [markdown]
# Transforms the `df_parsed` DataFrame by selecting and converting date-related fields into various formats, including day, month, quarter, and year. The resulting `df_date` DataFrame provides a structured representation of these date attributes for analysis.

# %%
df_date.printSchema()
# Out:
# root
#  |-- Date_ID: long (nullable = true)
#  |-- Date: date (nullable = true)
#  |-- Day: integer (nullable = true)
#  |-- Day_Name: string (nullable = true)
#  |-- Month: integer (nullable = true)
#  |-- Month_Name: string (nullable = true)
#  |-- Quarter: integer (nullable = true)
#  |-- Year: integer (nullable = true)

# %% [markdown]
# ### Time Dimension

# %%
from pyspark.sql.functions import hour, minute, to_timestamp

df_time = df_parsed.selectExpr("CAST(eventOffset AS BIGINT) as Time_ID",
                               "to_timestamp(Time) as Time", 
                               "hour(to_timestamp(Time)) as Hour", 
                               "minute(to_timestamp(Time)) as Minute")


# Reordering the DataFrame to match the schema order
df_time = df_time.select("Time_ID", "Time", "Hour", "Minute")

# %% [markdown]
# Transforms the `df_parsed` DataFrame by selecting and converting time-related fields, including the event offset and time components, into a structured format. The resulting `df_time` DataFrame includes fields for a unique `Time_ID`, the full timestamp, hour, and minute for easier time-based analysis.

# %%
df_time.printSchema()
# Out:
# root
#  |-- Time_ID: long (nullable = true)
#  |-- Time: timestamp (nullable = true)
#  |-- Hour: integer (nullable = true)
#  |-- Minute: integer (nullable = true)

# %% [markdown]
# ### Location Dimension

# %%
# Assuming df_parsed is already defined and contains columns: Easting, Northing, Location, Local_Auth
df_location = df_parsed.selectExpr(
    "CAST(eventOffset AS BIGINT) as Location_ID",
    "Easting as Easting", 
    "Northing as Northing", 
    "Location as Location", 
    "Local_Auth as Local_Authority"  
)

# Reordering the DataFrame to match the schema order
df_location = df_location.select("Location_ID", "Easting", "Northing", "Location", "Local_Authority")

# %%
df_location.printSchema()
# Out:
# root
#  |-- Location_ID: long (nullable = true)
#  |-- Easting: integer (nullable = true)
#  |-- Northing: integer (nullable = true)
#  |-- Location: string (nullable = true)
#  |-- Local_Authority: string (nullable = true)

# %% [markdown]
# ### Severity Dimension

# %%
df_severity = df_parsed.selectExpr(
    "CAST(eventOffset AS BIGINT) as Severity_ID",
    "Severity as Severity"  
)

# Reordering the DataFrame to match the schema order
df_severity = df_severity.select("Severity_ID", "Severity")

# %%
df_severity.printSchema()
# Out:
# root
#  |-- Severity_ID: long (nullable = true)
#  |-- Severity: string (nullable = true)

# %% [markdown]
# ### Road Condition Dimension

# %%
# Assuming df_parsed is already defined and contains the relevant columns
df_road_condition = df_parsed.selectExpr(
    "CAST(eventOffset AS BIGINT) as Road_Condition_ID",
    "Road_cond as Road_Condition", 
    "Weather as Weather", 
    "Visibility as Visibility", 
    "Speed_Lim as Speed_Limit"
)

# Reordering the DataFrame to match the schema order
df_road_condition = df_road_condition.select(
    "Road_Condition_ID", 
    "Road_Condition", 
    "Weather", 
    "Visibility", 
    "Speed_Limit"
)

# %%
df_road_condition.printSchema()
# Out:
# root
#  |-- Road_Condition_ID: long (nullable = true)
#  |-- Road_Condition: string (nullable = true)
#  |-- Weather: string (nullable = true)
#  |-- Visibility: string (nullable = true)
#  |-- Speed_Limit: integer (nullable = true)

# %% [markdown]
# ### Crossing Dimension

# %%
# Assuming df_parsed is already defined and contains the relevant columns
df_crossing = df_parsed.selectExpr(
    "CAST(eventOffset AS BIGINT) as Crossing_ID",
    "Cross_fac as Crossing_Facility", 
    "Cross_ctrl as Crossing_Control_Type"
)

# Reordering the DataFrame to match the schema order
df_crossing = df_crossing.select(
    "Crossing_ID", 
    "Crossing_Facility", 
    "Crossing_Control_Type"
)

# %%
df_crossing.printSchema()
# Out:
# root
#  |-- Crossing_ID: long (nullable = true)
#  |-- Crossing_Facility: string (nullable = true)
#  |-- Crossing_Control_Type: string (nullable = true)

# %% [markdown]
# ### Finally, Fact Table

# %%
# Fact table with IDs from dimensions based on matching columns
df_fact = df_parsed.selectExpr(
                "Police_ref as Police_Ref",
                "CAST(eventOffset AS BIGINT) as Date_ID",
                "CAST(eventOffset AS BIGINT) as Time_ID",
                "CAST(eventOffset AS BIGINT) as Severity_ID",
                "CAST(eventOffset AS BIGINT) as Location_ID",
                "CAST(eventOffset AS BIGINT) as Road_Condition_ID",
                "CAST(eventOffset AS BIGINT) as Crossing_ID",
                "Casualties as Number_Of_Casualties", 
                "OAPs as Number_Of_OAPs", 
                "Children as Number_Of_Children", 
                "Cycles as Cycles_Involved", 
                "P2W as P2W_Involved", 
                "Pedestrian as Pedestrians_Involved", 
                "Vehicles as Motor_Vehicles_Involved")

# %%
df_fact.printSchema()
# Out:
# root
#  |-- Police_Ref: string (nullable = true)
#  |-- Date_ID: long (nullable = true)
#  |-- Time_ID: long (nullable = true)
#  |-- Severity_ID: long (nullable = true)
#  |-- Location_ID: long (nullable = true)
#  |-- Road_Condition_ID: long (nullable = true)
#  |-- Crossing_ID: long (nullable = true)
#  |-- Number_Of_Casualties: integer (nullable = true)
#  |-- Number_Of_OAPs: integer (nullable = true)
#  |-- Number_Of_Children: integer (nullable = true)
#  |-- Cycles_Involved: integer (nullable = true)
#  |-- P2W_Involved: integer (nullable = true)
#  |-- Pedestrians_Involved: integer (nullable = true)
#  |-- Motor_Vehicles_Involved: integer (nullable = true)

# %%
# Select final columns for the fact table
fact_incidents = df_fact.select(
    "Police_Ref",
    "Date_ID",
    "Time_ID",
    "Severity_ID",
    "Location_ID",
    "Road_Condition_ID",
    "Crossing_ID",
    "Number_Of_Casualties",
    "Number_Of_OAPs",
    "Number_Of_Children",
    "Cycles_Involved",
    "P2W_Involved",
    "Pedestrians_Involved",
    "Motor_Vehicles_Involved"
)

# %%
fact_incidents.printSchema()
# Out:
# root
#  |-- Police_Ref: string (nullable = true)
#  |-- Date_ID: long (nullable = true)
#  |-- Time_ID: long (nullable = true)
#  |-- Severity_ID: long (nullable = true)
#  |-- Location_ID: long (nullable = true)
#  |-- Road_Condition_ID: long (nullable = true)
#  |-- Crossing_ID: long (nullable = true)
#  |-- Number_Of_Casualties: integer (nullable = true)
#  |-- Number_Of_OAPs: integer (nullable = true)
#  |-- Number_Of_Children: integer (nullable = true)
#  |-- Cycles_Involved: integer (nullable = true)
#  |-- P2W_Involved: integer (nullable = true)
#  |-- Pedestrians_Involved: integer (nullable = true)
#  |-- Motor_Vehicles_Involved: integer (nullable = true)

# %% [markdown]
# # Load Phase

# %% [markdown]
# ## 6. Load Function

# %%
# Function to load DataFrame to MySQL
# host = "database" or host = "172.18.0.3"

def load_to_MySQL(batch_df, batch_id, table_name):
    print(f"Batch id: {batch_id} for table {table_name}")
    try:
        batch_df.write \
            .mode("append") \
            .format("jdbc") \
            .option("driver", "com.mysql.cj.jdbc.Driver") \
            .option("url", "jdbc:mysql://database:3306/incidents_DW") \
            .option("dbtable", table_name) \
            .option("user", "root") \
            .option("password", "123456") \
            .save()
    except Exception as e:
        print(f"Error writing to MySQL: {e}")

# %% [markdown]
# The `load_to_MySQL` function writes a given DataFrame (`batch_df`) to a specified MySQL table (`table_name`) in append mode, while logging the batch ID. It establishes a JDBC connection using provided credentials and handles any exceptions during the writing process.

# %% [markdown]
# ## Automated Batch Loading of Dimension Tables

# %%
# Load the dim tables
query_date = (df_date.writeStream
              .foreachBatch(lambda batch_df, batch_id: load_to_MySQL(batch_df, batch_id, "dim_date"))
              .trigger(processingTime='8 seconds')
              .option("checkpointLocation", "checkpoint_dir_kafka_date")
              .start()
             )

query_time = (df_time.writeStream
              .foreachBatch(lambda batch_df, batch_id: load_to_MySQL(batch_df, batch_id, "dim_time"))
              .trigger(processingTime='8 seconds')
              .option("checkpointLocation", "checkpoint_dir_kafka_time")
              .start()
             )

query_severity = (df_severity.writeStream
              .foreachBatch(lambda batch_df, batch_id: load_to_MySQL(batch_df, batch_id, "dim_severity"))
              .trigger(processingTime='8 seconds')
              .option("checkpointLocation", "checkpoint_dir_kafka_severity")
              .start()
             )

query_location = (df_location.writeStream
              .foreachBatch(lambda batch_df, batch_id: load_to_MySQL(batch_df, batch_id, "dim_location"))
              .trigger(processingTime='8 seconds')
              .option("checkpointLocation", "checkpoint_dir_kafka_location")
              .start()
             )

query_road_condition = (df_road_condition.writeStream
              .foreachBatch(lambda batch_df, batch_id: load_to_MySQL(batch_df, batch_id, "dim_road_condition"))
              .trigger(processingTime='8 seconds')
              .option("checkpointLocation", "checkpoint_dir_kafka_road_condition")
              .start()
             )

query_crossing = (df_crossing.writeStream
              .foreachBatch(lambda batch_df, batch_id: load_to_MySQL(batch_df, batch_id, "dim_crossing"))
              .trigger(processingTime='8 seconds')
              .option("checkpointLocation", "checkpoint_dir_kafka_crossing")
              .start()
             )

# %%
# Load the fact table
query_fact = (fact_incidents.writeStream
              .foreachBatch(lambda batch_df, batch_id: load_to_MySQL(batch_df, batch_id, "fact_incidents"))
              .trigger(processingTime='8 seconds')
              .option("checkpointLocation", "checkpoint_dir_kafka_fact")
              .start()
             )

# %%
# Wait for termination
query_date.awaitTermination()
query_time.awaitTermination()
query_severity.awaitTermination()
query_location.awaitTermination()
query_road_condition.awaitTermination()
query_crossing.awaitTermination()


query_fact.awaitTermination()
# Out:
# Batch id: 6 for table fact_incidents
# Batch id: 6 for table dim_road_condition
# Batch id: 6 for table dim_crossing
# Batch id: 6 for table dim_severity
# Batch id: 6 for table dim_time
# Batch id: 6 for table dim_date
# Batch id: 6 for table dim_location
# Batch id: 7 for table dim_crossing
# Batch id: 7 for table dim_location
# Batch id: 7 for table dim_severity
# Batch id: 7 for table dim_road_condition
# Batch id: 7 for table dim_time
# Batch id: 7 for table fact_incidents
# Batch id: 7 for table dim_date
# Batch id: 8 for table dim_crossing
# Batch id: 8 for table dim_severity
# Batch id: 8 for table dim_location
# Batch id: 8 for table dim_time
# Batch id: 8 for table dim_road_condition
# Batch id: 8 for table dim_date
# Batch id: 8 for table fact_incidents
# Batch id: 9 for table dim_road_condition
# Batch id: 9 for table dim_date
# Batch id: 9 for table dim_time
# Batch id: 9 for table dim_crossing
# Batch id: 9 for table dim_severity
# Batch id: 9 for table fact_incidents
# Batch id: 9 for table dim_location
# Batch id: 10 for table dim_location
# Batch id: 10 for table dim_date
# Batch id: 10 for table dim_road_condition
# Batch id: 10 for table dim_crossing
# Batch id: 10 for table dim_severity
# Batch id: 10 for table fact_incidents
# Batch id: 10 for table dim_time
# Batch id: 11 for table dim_crossing
# Batch id: 11 for table dim_road_condition
# Batch id: 11 for table dim_severity
# Batch id: 11 for table dim_location
# Batch id: 11 for table dim_time
# Batch id: 11 for table dim_date
# Batch id: 11 for table fact_incidents
# Batch id: 12 for table dim_crossing
# Batch id: 12 for table dim_road_condition
# Batch id: 12 for table dim_severity
# Batch id: 12 for table dim_time
# Batch id: 12 for table dim_date
# Batch id: 12 for table dim_location
# Batch id: 12 for table fact_incidents
# Batch id: 13 for table dim_crossing
# Batch id: 13 for table dim_location
# Batch id: 13 for table dim_time
# Batch id: 13 for table dim_severity
# Batch id: 13 for table dim_road_condition
# Batch id: 13 for table dim_date
# Batch id: 13 for table fact_incidents
# Batch id: 14 for table dim_crossing
# Batch id: 14 for table dim_severity
# Batch id: 14 for table dim_time
# Batch id: 14 for table fact_incidents
# Batch id: 14 for table dim_date
# Batch id: 14 for table dim_location
# Batch id: 14 for table dim_road_condition
# Batch id: 15 for table dim_severity
# Batch id: 15 for table dim_crossing
# Batch id: 15 for table dim_road_condition
# Batch id: 15 for table fact_incidents
# Batch id: 15 for table dim_location
# Batch id: 15 for table dim_date
# Batch id: 15 for table dim_time
# Batch id: 16 for table fact_incidents
# Batch id: 16 for table dim_severity
# Batch id: 16 for table dim_location
# Batch id: 16 for table dim_crossing
# Batch id: 16 for table dim_road_condition
# Batch id: 16 for table dim_date
# Batch id: 16 for table dim_time
# Batch id: 17 for table dim_road_condition
# Batch id: 17 for table dim_location
# Batch id: 17 for table dim_severity
# Batch id: 17 for table dim_date
# Batch id: 17 for table fact_incidents
# Batch id: 17 for table dim_crossing
# Batch id: 17 for table dim_time
# Batch id: 18 for table dim_date
# Batch id: 18 for table dim_severity
# Batch id: 18 for table fact_incidents
# Batch id: 18 for table dim_location
# Batch id: 18 for table dim_crossing
# Batch id: 18 for table dim_road_condition
# Batch id: 18 for table dim_time
# Batch id: 19 for table dim_severity
# Batch id: 19 for table dim_location
# Batch id: 19 for table dim_date
# Batch id: 19 for table dim_crossing
# Batch id: 19 for table dim_road_condition
# Batch id: 19 for table dim_time
# Batch id: 19 for table fact_incidents
# Batch id: 20 for table dim_severity
# Batch id: 20 for table dim_date
# Batch id: 20 for table dim_location
# Batch id: 20 for table dim_crossing
# Batch id: 20 for table dim_road_condition
# Batch id: 20 for table dim_time
# Batch id: 20 for table fact_incidents
# Batch id: 21 for table dim_crossing
# Batch id: 21 for table dim_road_condition
# Batch id: 21 for table dim_severity
# Batch id: 21 for table fact_incidents
# Batch id: 21 for table dim_time
# Batch id: 21 for table dim_location
# Batch id: 21 for table dim_date
# Batch id: 22 for table fact_incidents
# Batch id: 22 for table dim_road_condition
# Batch id: 22 for table dim_crossing
# Batch id: 22 for table dim_severity
# Batch id: 22 for table dim_date
# Batch id: 22 for table dim_location
# Batch id: 22 for table dim_time
# Batch id: 23 for table fact_incidents
# Batch id: 23 for table dim_severity
# Batch id: 23 for table dim_road_condition
# Batch id: 23 for table dim_crossing
# Batch id: 23 for table dim_date
# Batch id: 23 for table dim_time
# Batch id: 23 for table dim_location
# Batch id: 24 for table dim_severity
# Batch id: 24 for table dim_time
# Batch id: 24 for table dim_location
# Batch id: 24 for table dim_road_condition
# Batch id: 24 for table dim_crossing
# Batch id: 24 for table fact_incidents
# Batch id: 24 for table dim_date
# Batch id: 25 for table dim_road_condition
# Batch id: 25 for table dim_location
# Batch id: 25 for table dim_crossing
# Batch id: 25 for table dim_time
# Batch id: 25 for table dim_date
# Batch id: 25 for table dim_severity
# Batch id: 25 for table fact_incidents
# Batch id: 26 for table dim_crossing
# Batch id: 26 for table dim_severity
# Batch id: 26 for table dim_time
# Batch id: 26 for table dim_location
# Batch id: 26 for table dim_date
# Batch id: 26 for table fact_incidents
# Batch id: 26 for table dim_road_condition
# Batch id: 27 for table dim_crossing
# Batch id: 27 for table dim_time
# Batch id: 27 for table dim_road_condition
# Batch id: 27 for table dim_date
# Batch id: 27 for table fact_incidents
# Batch id: 27 for table dim_severity
# Batch id: 27 for table dim_location
# Batch id: 28 for table dim_severity
# Batch id: 28 for table dim_time
# Batch id: 28 for table dim_location
# Batch id: 28 for table dim_crossing
# Batch id: 28 for table dim_date
# Batch id: 28 for table fact_incidents
# Batch id: 28 for table dim_road_condition
# Batch id: 29 for table dim_road_condition
# Batch id: 29 for table dim_crossing
# Batch id: 29 for table dim_severity
# Batch id: 29 for table dim_time
# Batch id: 29 for table dim_date
# Batch id: 29 for table dim_location
# Batch id: 29 for table fact_incidents
# Batch id: 30 for table dim_crossing
# Batch id: 30 for table dim_severity
# Batch id: 30 for table dim_date
# Batch id: 30 for table dim_time
# Batch id: 30 for table dim_location
# Batch id: 30 for table fact_incidents
# Batch id: 30 for table dim_road_condition
# Batch id: 31 for table dim_road_condition
# Batch id: 31 for table dim_date
# Batch id: 31 for table dim_location
# Batch id: 31 for table dim_time
# Batch id: 31 for table fact_incidents
# Batch id: 31 for table dim_crossing
# Batch id: 31 for table dim_severity
# Batch id: 32 for table dim_crossing
# Batch id: 32 for table dim_location
# Batch id: 32 for table dim_time
# Batch id: 32 for table dim_severity
# Batch id: 32 for table dim_road_condition
# Batch id: 32 for table fact_incidents
# Batch id: 32 for table dim_date
# Batch id: 33 for table dim_location
# Batch id: 33 for table dim_crossing
# Batch id: 33 for table dim_road_condition
# Batch id: 33 for table dim_severity
# Batch id: 33 for table dim_time
# Batch id: 33 for table dim_date
# Batch id: 33 for table fact_incidents
# Batch id: 34 for table dim_road_condition
# Batch id: 34 for table dim_time
# Batch id: 34 for table dim_severity
# Batch id: 34 for table dim_crossing
# Batch id: 34 for table dim_location
# Batch id: 34 for table dim_date
# Batch id: 34 for table fact_incidents
# Batch id: 35 for table fact_incidents
# Batch id: 35 for table dim_crossing
# Batch id: 35 for table dim_time
# Batch id: 35 for table dim_date
# Batch id: 35 for table dim_severity
# Batch id: 35 for table dim_road_condition
# Batch id: 35 for table dim_location
# Batch id: 36 for table dim_time
# Batch id: 36 for table dim_crossing
# Batch id: 36 for table dim_location
# Batch id: 36 for table fact_incidents
# Batch id: 36 for table dim_severity
# Batch id: 36 for table dim_road_condition
# Batch id: 36 for table dim_date
# Batch id: 37 for table dim_date
# Batch id: 37 for table fact_incidents
# Batch id: 37 for table dim_crossing
# Batch id: 37 for table dim_severity
# Batch id: 37 for table dim_time
# Batch id: 37 for table dim_road_condition
# Batch id: 37 for table dim_location
# Batch id: 38 for table dim_time
# Batch id: 38 for table fact_incidents
# Batch id: 38 for table dim_severity
# Batch id: 38 for table dim_road_condition
# Batch id: 38 for table dim_location
# Batch id: 38 for table dim_date
# Batch id: 38 for table dim_crossing
# Batch id: 39 for table dim_time
# Batch id: 39 for table dim_date
# Batch id: 39 for table dim_location
# Batch id: 39 for table dim_crossing
# Batch id: 39 for table dim_severity
# Batch id: 39 for table dim_road_condition
# Batch id: 39 for table fact_incidents
# Batch id: 40 for table dim_severity
# Batch id: 40 for table dim_location
# Batch id: 40 for table fact_incidents
# Batch id: 40 for table dim_road_condition
# Batch id: 40 for table dim_date
# Batch id: 40 for table dim_time
# Batch id: 40 for table dim_crossing
# Batch id: 41 for table dim_severity
# Batch id: 41 for table dim_location
# Batch id: 41 for table dim_road_condition
# Batch id: 41 for table dim_crossing
# Batch id: 41 for table dim_time
# Batch id: 41 for table dim_date
# Batch id: 41 for table fact_incidents
# Batch id: 42 for table dim_road_condition
# Batch id: 42 for table dim_severity
# Batch id: 42 for table dim_crossing
# Batch id: 42 for table fact_incidents
# Batch id: 42 for table dim_location
# Batch id: 42 for table dim_date
# Batch id: 42 for table dim_time
# Batch id: 43 for table dim_location
# Batch id: 43 for table dim_severity
# Batch id: 43 for table dim_road_condition
# Batch id: 43 for table dim_crossing
# Batch id: 43 for table dim_date
# Batch id: 43 for table fact_incidents
# Batch id: 43 for table dim_time
# Batch id: 44 for table dim_date
# Batch id: 44 for table dim_severity
# Batch id: 44 for table dim_road_condition
# Batch id: 44 for table dim_time
# Batch id: 44 for table dim_location
# Batch id: 44 for table dim_crossing
# Batch id: 44 for table fact_incidents
# Batch id: 45 for table dim_location
# Batch id: 45 for table dim_time
# Batch id: 45 for table dim_crossing
# Batch id: 45 for table dim_severity
# Batch id: 45 for table dim_date
# Batch id: 45 for table fact_incidents
# Batch id: 45 for table dim_road_condition
# Batch id: 46 for table dim_time
# Batch id: 46 for table dim_location
# Batch id: 46 for table dim_road_condition
# Batch id: 46 for table dim_crossing
# Batch id: 46 for table dim_severity
# Batch id: 46 for table dim_date
# Batch id: 46 for table fact_incidents
# Batch id: 47 for table dim_crossing
# Batch id: 47 for table dim_date
# Batch id: 47 for table dim_time
# Batch id: 47 for table dim_road_condition
# Batch id: 47 for table dim_severity
# Batch id: 47 for table fact_incidents
# Batch id: 47 for table dim_location
# Batch id: 48 for table dim_time
# Batch id: 48 for table dim_crossing
# Batch id: 48 for table dim_location
# Batch id: 48 for table fact_incidents
# Batch id: 48 for table dim_road_condition
# Batch id: 48 for table dim_date
# Batch id: 48 for table dim_severity
# Batch id: 49 for table dim_time
# Batch id: 49 for table dim_crossing
# Batch id: 49 for table dim_date
# Batch id: 49 for table dim_severity
# Batch id: 49 for table dim_location
# Batch id: 49 for table fact_incidents
# Batch id: 49 for table dim_road_condition
# Batch id: 50 for table dim_time
# Batch id: 50 for table dim_road_condition
# Batch id: 50 for table fact_incidents
# Batch id: 50 for table dim_date
# Batch id: 50 for table dim_severity
# Batch id: 50 for table dim_location
# Batch id: 50 for table dim_crossing
# Batch id: 51 for table dim_crossing
# Batch id: 51 for table dim_time
# Batch id: 51 for table dim_date
# Batch id: 51 for table fact_incidents
# Batch id: 51 for table dim_severity
# Batch id: 51 for table dim_road_condition
# Batch id: 51 for table dim_location
# Batch id: 52 for table dim_severity
# Batch id: 52 for table dim_road_condition
# Batch id: 52 for table dim_date
# Batch id: 52 for table dim_crossing
# Batch id: 52 for table fact_incidents
# Batch id: 52 for table dim_location
# Batch id: 52 for table dim_time
# Batch id: 53 for table dim_severity
# Batch id: 53 for table dim_location
# Batch id: 53 for table dim_date
# Batch id: 53 for table dim_crossing
# Batch id: 53 for table fact_incidents
# Batch id: 53 for table dim_time
# Batch id: 53 for table dim_road_condition
# Batch id: 54 for table dim_road_condition
# Batch id: 54 for table fact_incidents
# Batch id: 54 for table dim_severity
# Batch id: 54 for table dim_date
# Batch id: 54 for table dim_crossing
# Batch id: 54 for table dim_time
# Batch id: 54 for table dim_location
# Batch id: 55 for table dim_crossing
# Batch id: 55 for table dim_time
# Batch id: 55 for table dim_severity
# Batch id: 55 for table fact_incidents
# Batch id: 55 for table dim_road_condition
# Batch id: 55 for table dim_date
# Batch id: 55 for table dim_location
# Batch id: 56 for table dim_severity
# Batch id: 56 for table dim_location
# Batch id: 56 for table dim_road_condition
# Batch id: 56 for table dim_crossing
# Batch id: 56 for table fact_incidents
# Batch id: 56 for table dim_date
# Batch id: 56 for table dim_time
# Batch id: 57 for table dim_location
# Batch id: 57 for table fact_incidents
# Batch id: 57 for table dim_crossing
# Batch id: 57 for table dim_severity
# Batch id: 57 for table dim_road_condition
# Batch id: 57 for table dim_time
# Batch id: 57 for table dim_date
# Batch id: 58 for table dim_time
# Batch id: 58 for table dim_crossing
# Batch id: 58 for table dim_location
# Batch id: 58 for table dim_road_condition
# Batch id: 58 for table dim_severity
# Batch id: 58 for table dim_date
# Batch id: 58 for table fact_incidents
# Batch id: 59 for table dim_road_condition
# Batch id: 59 for table dim_severity
# Batch id: 59 for table dim_time
# Batch id: 59 for table dim_location
# Batch id: 59 for table fact_incidents
# Batch id: 59 for table dim_crossing
# Batch id: 59 for table dim_date
# Batch id: 60 for table dim_location
# Batch id: 60 for table dim_time
# Batch id: 60 for table dim_severity
# Batch id: 60 for table dim_crossing
# Batch id: 60 for table fact_incidents
# Batch id: 60 for table dim_date
# Batch id: 60 for table dim_road_condition
# Batch id: 61 for table dim_time
# Batch id: 61 for table dim_date
# Batch id: 61 for table dim_location
# Batch id: 61 for table dim_severity
# Batch id: 61 for table dim_road_condition
# Batch id: 61 for table dim_crossing
# Batch id: 61 for table fact_incidents
# Batch id: 62 for table dim_crossing
# Batch id: 62 for table dim_location
# Batch id: 62 for table dim_time
# Batch id: 62 for table dim_date
# Batch id: 62 for table fact_incidents
# Batch id: 62 for table dim_road_condition
# Batch id: 62 for table dim_severity
# Batch id: 63 for table dim_severity
# Batch id: 63 for table dim_time
# Batch id: 63 for table fact_incidents
# Batch id: 63 for table dim_date
# Batch id: 63 for table dim_road_condition
# Batch id: 63 for table dim_crossing
# Batch id: 63 for table dim_location
# Batch id: 64 for table dim_severity
# Batch id: 64 for table dim_location
# Batch id: 64 for table dim_time
# Batch id: 64 for table dim_crossing
# Batch id: 64 for table fact_incidents
# Batch id: 64 for table dim_date
# Batch id: 64 for table dim_road_condition
# Batch id: 65 for table dim_location
# Batch id: 65 for table dim_crossing
# Batch id: 65 for table dim_road_condition
# Batch id: 65 for table dim_time
# Batch id: 65 for table dim_severity
# Batch id: 65 for table fact_incidents
# Batch id: 65 for table dim_date
# Batch id: 66 for table dim_crossing
# Batch id: 66 for table fact_incidents
# Batch id: 66 for table dim_road_condition
# Batch id: 66 for table dim_location
# Batch id: 66 for table dim_date
# Batch id: 66 for table dim_severity
# Batch id: 66 for table dim_time
# Batch id: 67 for table dim_crossing
# Batch id: 67 for table fact_incidents
# Batch id: 67 for table dim_road_condition
# Batch id: 67 for table dim_date
# Batch id: 67 for table dim_severity
# Batch id: 67 for table dim_location
# Batch id: 67 for table dim_time
# Batch id: 68 for table dim_road_conditionBatch id: 68 for table fact_incidents
# Batch id: 68 for table dim_crossing
# Batch id: 68 for table dim_time
# Batch id: 68 for table dim_date
# Batch id: 68 for table dim_location
# Batch id: 68 for table dim_severity
